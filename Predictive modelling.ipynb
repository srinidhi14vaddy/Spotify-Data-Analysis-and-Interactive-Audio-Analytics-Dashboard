# %%
import pandas as pd
import numpy as np
import json

# %%
# Read in track metadata with genre labels
tracks = pd.read_csv('fma-rock-vs-hiphop.csv')

# Read in track metrics with the features
echonest_metrics = pd.read_json('echonest-metrics-2.json',precise_float = True)

# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = pd.merge(echonest_metrics, tracks[["track_id", "genre_top"]], on="track_id")

# Inspect the resultant dataframe

echo_tracks.head()
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3       134      0.452217      0.513238  0.560410          0.019443  0.096567
# 4       153      0.988306      0.255661  0.979774          0.973006  0.121342
#
#    speechiness    tempo   valence genre_top
# 0     0.159310  165.922  0.576661   Hip-Hop
# 1     0.461818  126.957  0.269240   Hip-Hop
# 2     0.124595  100.260  0.621661   Hip-Hop
# 3     0.525519  114.290  0.894072   Hip-Hop
# 4     0.051740   90.241  0.034018      Rock

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0bdb9_row0_col0, #T_0bdb9_row1_col1, #T_0bdb9_row2_col2, #T_0bdb9_row3_col3, #T_0bdb9_row4_col4, #T_0bdb9_row5_col5, #T_0bdb9_row6_col6, #T_0bdb9_row7_col7, #T_0bdb9_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0bdb9_row0_col1, #T_0bdb9_row1_col0, #T_0bdb9_row1_col3, #T_0bdb9_row2_col5, #T_0bdb9_row2_col7, #T_0bdb9_row4_col2, #T_0bdb9_row4_col6, #T_0bdb9_row4_col8, #T_0bdb9_row6_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0bdb9_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_0bdb9_row0_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_0bdb9_row0_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_0bdb9_row0_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_0bdb9_row0_col6, #T_0bdb9_row8_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_0bdb9_row0_col7, #T_0bdb9_row1_col7 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_0bdb9_row0_col8, #T_0bdb9_row3_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_0bdb9_row1_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_0bdb9_row1_col4, #T_0bdb9_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_0bdb9_row1_col5, #T_0bdb9_row2_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_0bdb9_row1_col6, #T_0bdb9_row6_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_0bdb9_row1_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_0bdb9_row2_col0, #T_0bdb9_row5_col0, #T_0bdb9_row5_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_0bdb9_row2_col1, #T_0bdb9_row6_col0, #T_0bdb9_row7_col0, #T_0bdb9_row7_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_0bdb9_row2_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_0bdb9_row2_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_0bdb9_row2_col8 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_0bdb9_row3_col0, #T_0bdb9_row7_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_0bdb9_row3_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_0bdb9_row3_col2, #T_0bdb9_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_0bdb9_row3_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_0bdb9_row3_col5, #T_0bdb9_row5_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_0bdb9_row3_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_0bdb9_row3_col8, #T_0bdb9_row4_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_0bdb9_row4_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_0bdb9_row4_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_0bdb9_row4_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_0bdb9_row5_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_0bdb9_row5_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_0bdb9_row5_col4, #T_0bdb9_row6_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_0bdb9_row5_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_0bdb9_row5_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_0bdb9_row6_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_0bdb9_row6_col3, #T_0bdb9_row6_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_0bdb9_row6_col8 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_0bdb9_row7_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_0bdb9_row7_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_0bdb9_row7_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_0bdb9_row7_col8 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_0bdb9_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_0bdb9_row8_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_0bdb9_row8_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_0bdb9_row8_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_0bdb9_row8_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_0bdb9_row8_col6 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_0bdb9_row8_col7 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_0bdb9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >track_id</th>
#       <th class="col_heading level0 col1" >acousticness</th>
#       <th class="col_heading level0 col2" >danceability</th>
#       <th class="col_heading level0 col3" >energy</th>
#       <th class="col_heading level0 col4" >instrumentalness</th>
#       <th class="col_heading level0 col5" >liveness</th>
#       <th class="col_heading level0 col6" >speechiness</th>
#       <th class="col_heading level0 col7" >tempo</th>
#       <th class="col_heading level0 col8" >valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bdb9_level0_row0" class="row_heading level0 row0" >track_id</th>
#       <td id="T_0bdb9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0bdb9_row0_col1" class="data row0 col1" >-0.372282</td>
#       <td id="T_0bdb9_row0_col2" class="data row0 col2" >0.049454</td>
#       <td id="T_0bdb9_row0_col3" class="data row0 col3" >0.140703</td>
#       <td id="T_0bdb9_row0_col4" class="data row0 col4" >-0.275623</td>
#       <td id="T_0bdb9_row0_col5" class="data row0 col5" >0.048231</td>
#       <td id="T_0bdb9_row0_col6" class="data row0 col6" >-0.026995</td>
#       <td id="T_0bdb9_row0_col7" class="data row0 col7" >-0.025392</td>
#       <td id="T_0bdb9_row0_col8" class="data row0 col8" >0.010070</td>
#     </tr>
#     <tr>
#       <th id="T_0bdb9_level0_row1" class="row_heading level0 row1" >acousticness</th>
#       <td id="T_0bdb9_row1_col0" class="data row1 col0" >-0.372282</td>
#       <td id="T_0bdb9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0bdb9_row1_col2" class="data row1 col2" >-0.028954</td>
#       <td id="T_0bdb9_row1_col3" class="data row1 col3" >-0.281619</td>
#       <td id="T_0bdb9_row1_col4" class="data row1 col4" >0.194780</td>
#       <td id="T_0bdb9_row1_col5" class="data row1 col5" >-0.019991</td>
#       <td id="T_0bdb9_row1_col6" class="data row1 col6" >0.072204</td>
#       <td id="T_0bdb9_row1_col7" class="data row1 col7" >-0.026310</td>
#       <td id="T_0bdb9_row1_col8" class="data row1 col8" >-0.013841</td>
#     </tr>
#     <tr>
#       <th id="T_0bdb9_level0_row2" class="row_heading level0 row2" >danceability</th>
#       <td id="T_0bdb9_row2_col0" class="data row2 col0" >0.049454</td>
#       <td id="T_0bdb9_row2_col1" class="data row2 col1" >-0.028954</td>
#       <td id="T_0bdb9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0bdb9_row2_col3" class="data row2 col3" >-0.242032</td>
#       <td id="T_0bdb9_row2_col4" class="data row2 col4" >-0.255217</td>
#       <td id="T_0bdb9_row2_col5" class="data row2 col5" >-0.106584</td>
#       <td id="T_0bdb9_row2_col6" class="data row2 col6" >0.276206</td>
#       <td id="T_0bdb9_row2_col7" class="data row2 col7" >-0.242089</td>
#       <td id="T_0bdb9_row2_col8" class="data row2 col8" >0.473165</td>
#     </tr>
#     <tr>
#       <th id="T_0bdb9_level0_row3" class="row_heading level0 row3" >energy</th>
#       <td id="T_0bdb9_row3_col0" class="data row3 col0" >0.140703</td>
#       <td id="T_0bdb9_row3_col1" class="data row3 col1" >-0.281619</td>
#       <td id="T_0bdb9_row3_col2" class="data row3 col2" >-0.242032</td>
#       <td id="T_0bdb9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0bdb9_row3_col4" class="data row3 col4" >0.028238</td>
#       <td id="T_0bdb9_row3_col5" class="data row3 col5" >0.113331</td>
#       <td id="T_0bdb9_row3_col6" class="data row3 col6" >-0.109983</td>
#       <td id="T_0bdb9_row3_col7" class="data row3 col7" >0.195227</td>
#       <td id="T_0bdb9_row3_col8" class="data row3 col8" >0.038603</td>
#     </tr>
#     <tr>
#       <th id="T_0bdb9_level0_row4" class="row_heading level0 row4" >instrumentalness</th>
#       <td id="T_0bdb9_row4_col0" class="data row4 col0" >-0.275623</td>
#       <td id="T_0bdb9_row4_col1" class="data row4 col1" >0.194780</td>
#       <td id="T_0bdb9_row4_col2" class="data row4 col2" >-0.255217</td>
#       <

# %%
# Define our features 
features = echo_tracks.drop(["genre_top","track_id"], axis=1)

# Define our labels
labels = echo_tracks["genre_top"]

# %%
# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)

# %%
# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# This is just to make plots appear in the notebook
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

print("Explained variance ratio : \n{}".format(pca.explained_variance_ratio_))
print("\n")
print("Number of components = {}".format(pca.n_components_))
# Out:
# Explained variance ratio :
# [0.24297674 0.18044316 0.13650309 0.12994089 0.11056248 0.08302245
#  0.06923783 0.04731336]
#
#
# Number of components = 8

# %%
# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(8), exp_variance)
ax.set_xlabel('Principal Component #')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %%
# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot = (range(8), cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
n_components = 6

# %%
# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# %%
# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)
class_rep_tree = classification_report(test_labels, pred_labels_tree)
print("Decision Tree: \n", class_rep_tree)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Train our logistic regression and predict labels for the test set
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %%
# Subset only the hip-hop tracks, and then only the rock tracks
hop_only = echo_tracks.loc[echo_tracks["genre_top"]=="Hip-Hop"]
rock_only = echo_tracks.loc[echo_tracks["genre_top"]=="Hip-Hop"]

# sample the rocks songs to be the same number as there are hip-hop songs
rock_only = echo_tracks.loc[echo_tracks["genre_top"] == "Rock"].sample(len(hop_only), random_state=10)

# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat([rock_only, hop_only])

# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)


# In[ ]:


# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.74      0.73      0.74       230
#         Rock       0.73      0.74      0.73       225
#
#     accuracy                           0.74       455
#    macro avg       0.74      0.74      0.74       455
# weighted avg       0.74      0.74      0.74       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.84      0.80      0.82       230
#         Rock       0.80      0.85      0.83       225
#
#     accuracy                           0.82       455
#    macro avg       0.82      0.82      0.82       455
# weighted avg       0.82      0.82      0.82       455

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(n_splits=10)

tree = DecisionTreeClassifier()
logreg = LogisticRegression()

# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", np.mean(tree_score) , "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7483516483516484 Logistic Regression: 0.782967032967033
